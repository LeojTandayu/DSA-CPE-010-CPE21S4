# %% [markdown]
# <a href="https://colab.research.google.com/github/LeojTandayu/DSA-CPE-010-CPE21S4/blob/main/DSA_Hands_on_Activity_1_1_Using_Pseudo_code_Statements_and_Flowchart_Symbols_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem 1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Problem 2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
